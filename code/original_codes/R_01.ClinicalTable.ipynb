# %%
library(tableone)
library(ggplot2)
library(reshape2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 library(tableone)
#       2 library(ggplot2)
#       3 library(reshape2)
#
# NameError: name 'library' is not defined

# %%
Clinical = data.frame(read.csv("/mnt/e/EWHA/Pancreatic/Clinical.txt", sep="\t"))
Clinical$CA19_9_Base[Clinical$CA19_9_Base == '<5'] = "2.5"
Clinical$CA19_9_Base = as.numeric(Clinical$CA19_9_Base)

Clinical$CEA_Base[Clinical$CEA_Base == 'ND'] = "0.0"
Clinical$CEA_Base[Clinical$CEA_Base == '<3'] = "1.5"
Clinical$CEA_Base = as.numeric(Clinical$CEA_Base)

# %%
t(Clinical[Clinical[,'Study_no'] == 'PCAI0020',])
# Out:
#                    17
# Study_no           PCAI0020
# Sex                M
# Age                40
# P_of_total_ROI     17.0307
# Tx_1st             1
# size               1.5
# pT_8th             1
# N_stage            0
# cM1                0
# Tumor_location     2
# microvas_inv       2
# lymph_inv          2
# perineur_inv       1
# LN..._No           0
# LN_removed         26
# CA19_9_Base        24
# CEA_Base           1.4
# cf_DNA_Pre         0.481
# KRAS_C_Pre         0.1
# PFS_mo             60.06667
# PFS_event_Up220713 1
# SubGroup           Over3Yrs

# %%
nClass = unlist(lapply(Clinical[,-1], function(x) length(unique(x)))) < 5
Category_variables = names(which(nClass))
Numeric_variables = names(which(!nClass))

# %%
tableOne <- CreateTableOne(vars = colnames(Clinical)[-1], data = Clinical, factorVars = Category_variables)
print(tableOne, showAllLevels = TRUE)
# Out:
#
#                              level Overall
#   n                                   141
#   Sex (%)                    F         62 ( 44.0)
#                              M         79 ( 56.0)
#   Age (mean (SD))                   65.99 (9.82)
#   P_of_total_ROI (mean (SD))        33.67 (14.92)
#   Tx_1st (%)                 1        125 ( 88.7)
#                              2          2 (  1.4)
#                              3         13 (  9.2)
#                              5          1 (  0.7)
#   size (mean (SD))                   3.03 (1.49)
#   pT_8th (%)                 1         26 ( 19.0)
#                              2         89 ( 65.0)
#                              3         22 ( 16.1)
#   N_stage (%)                0         43 ( 30.9)
#                              1         77 ( 55.4)
#                              2         19 ( 13.7)
#   cM1 (%)                    0        141 (100.0)
#   Tumor_location (%)         1         77 ( 54.6)
#                              2         64 ( 45.4)
#   microvas_inv (%)           1         93 ( 66.0)
#                              2         48 ( 34.0)
#   lymph_inv (%)              1        107 ( 75.9)
#                              2         34 ( 24.1)
#   perineur_inv (%)           1        124 ( 89.2)
#                              2         15 ( 10.8)
#   LN..._No (mean (SD))               2.37 (3.18)
#   LN_removed (mean (SD))            22.36 (12.04)
#   CA19_9_Base (mean (SD))          228.79 (840.95)
#   CEA_Base (mean (SD))              12.31 (71.44)
#   cf_DNA_Pre (mean (SD))             1.04 (0.91)
#   KRAS_C_Pre (mean (SD))             0.58 (1.95)
#   PFS_mo (mean (SD))                24.56 (18.74)
#   PFS_event_Up220713 (%)     0         38 ( 27.0)
#                              1        103 ( 73.0)

# %%
Clinical$SubGroup = "Unknown"
Clinical$SubGroup[(Clinical$PFS_mo < 12) & (Clinical$PFS_event_Up220713==1)] = "Within1Yr"
Clinical$SubGroup[Clinical$PFS_mo > 36] = "Over3Yrs"
Clinical$SubGroup = factor(Clinical$SubGroup, levels=c("Over3Yrs", "Within1Yr", "Unknown"))

# %%
CreateTableOne
# Out:
# function (vars, strata, data, factorVars, includeNA = FALSE,
#     test = TRUE, testApprox = chisq.test, argsApprox = list(correct = TRUE),
#     testExact = fisher.test, argsExact = list(workspace = 2 *
#         10^5), testNormal = oneway.test, argsNormal = list(var.equal = TRUE),
#     testNonNormal = kruskal.test, argsNonNormal = list(NULL),
#     smd = TRUE, addOverall = FALSE)
# {
#     ModuleStopIfNotDataFrame(data)
#     if (missing(vars)) {
#         vars <- names(data)
#     }
#     vars <- ModuleReturnVarsExist(vars, data)
#     ModuleStopIfNoVarsLeft(vars)
#     varLabels <- labelled::var_label(data[vars])
#     if (!missing(factorVars)) {
#         factorVars <- ModuleReturnVarsExist(factorVars, data)
#         data[factorVars] <- lapply(data[factorVars], factor)
#     }
#     test <- ModuleReturnFalseIfNoStrata(strata, test)
#     smd <- ModuleReturnFalseIfNoStrata(strata, smd)
#     percentMissing <- ModulePercentMissing(data[vars])
#     varClasses <- lapply(data[vars], class)
#     varFactors <- sapply(varClasses, function(VEC) {
#         any(VEC %in% c("factor", "ordered", "logical", "character"))
#     })
#     varFactors <- names(varFactors)[varFactors]
#     varNumerics <- sapply(varClasses, function(VEC) {
#         any(VEC %in% c("numeric", "integer", "double"))
#     })
#     varNumerics <- names(varNumerics)[varNumerics]
#     varDrop <- setdiff(vars, c(varFactors, varNumerics))
#     if (length(varDrop) > 0) {
#         warning("Dropping variable(s) ", paste0(varDrop, sep = " "),
#             " due to unsupported class.\n")
#         vars <- setdiff(vars, varDrop)
#     }
#     logiFactors <- vars %in% varFactors
#     argsCreateContTable <- list(data = data, test = test, testNormal = testNormal,
#         argsNormal = argsNormal, testNonNormal = testNonNormal,
#         argsNonNormal = argsNonNormal, smd = smd, addOverall = addOverall)
#     argsCreateCatTable <- list(data = data, includeNA = includeNA,
#         test = test, testApprox = testApprox, argsApprox = argsApprox,
#         testExact = testExact, argsExact = argsExact, smd = smd,
#         addOverall = addOverall)
#     if (!missing(strata)) {
#         dfStrata <- ModuleReturnStrata(strata, data)
#         strata <- names(dfStrata)
#         argsCreateContTable <- c(list(strata = strata), argsCreateContTable)
#         argsCreateCatTable <- c(list(strata = strata), argsCreateCatTable)
#     }
#     if (length(varNumerics) == 0) {
#         ContTable <- NULL
#         CatTable <- do.call(CreateCatTable, args = c(list(vars = varFactors),
#             argsCreateCatTable))
#     }
#     else if (length(varFactors) == 0) {
#         ContTable <- do.call(CreateContTable, args = c(list(vars = varNumerics),
#             argsCreateContTable))
#         CatTable <- NULL
#     }
#     else if ((length(varFactors) > 0) & (length(varNumerics) >
#         0)) {
#         ContTable <- do.call(CreateContTable, args = c(list(vars = varNumerics),
#             argsCreateContTable))
#         CatTable <- do.call(CreateCatTable, args = c(list(vars = varFactors),
#             argsCreateCatTable))
#     }
#     else {
#         warning("No variables left to analyzed in vars.")
#     }
#     TableOneObject <- list(ContTable = ContTable, CatTable = CatTable,
#         MetaData = list(vars = vars, logiFactors = logiFactors,
#             varFactors = varFactors, varNumerics = varNumerics,
#             percentMissing = percentMissing, varLabels = varLabels))
#     class(TableOneObject) <- "TableOne"
#     return(TableOneObject)
# }
# <bytecode: 0x5614ec2f4930>
# <environment: namespace:tableone>

# %%
Clinical2 = data.frame(Clinical[Clinical$SubGroup != 'Unknown',])
Clinical2$SubGroup = factor(Clinical2$SubGroup)

# %%
options(width=240)
tableOne <- CreateTableOne(vars = colnames(Clinical)[-1], data = Clinical2, strata='SubGroup', factorVars = Category_variables)
print(tableOne, showAllLevels = TRUE)
# Out:
#                             Stratified by SubGroup
#                              level     Over3Yrs        Within1Yr        p      test
#   n                                        28              39
#   Sex (%)                    F             15 ( 53.6)      16 ( 41.0)    0.443
#                              M             13 ( 46.4)      23 ( 59.0)
#   Age (mean (SD))                       67.29 (9.90)    68.23 (10.81)    0.716
#   P_of_total_ROI (mean (SD))            30.74 (14.76)   36.74 (13.04)    0.083
#   Tx_1st (%)                 1             28 (100.0)      38 ( 97.4)    1.000
#                              5              0 (  0.0)       1 (  2.6)
#   size (mean (SD))                       2.27 (0.73)     3.55 (1.64)    <0.001
#   pT_8th (%)                 1             11 ( 40.7)       3 (  8.1)    0.001
#                              2             16 ( 59.3)      24 ( 64.9)
#                              3              0 (  0.0)      10 ( 27.0)
#   N_stage (%)                0             12 ( 42.9)      11 ( 28.2)    0.021
#                              1             16 ( 57.1)      19 ( 48.7)
#                              2              0 (  0.0)       9 ( 23.1)
#   cM1 (%)                    0             28 (100.0)      39 (100.0)       NA
#   Tumor_location (%)         1             15 ( 53.6)      27 ( 69.2)    0.293
#                              2             13 ( 46.4)      12 ( 30.8)
#   microvas_inv (%)           1             12 ( 42.9)      28 ( 71.8)    0.033
#                              2             16 ( 57.1)      11 ( 28.2)
#   lymph_inv (%)              1             16 ( 57.1)      34 ( 87.2)    0.012
#                              2             12 ( 42.9)       5 ( 12.8)
#   perineur_inv (%)           1             22 ( 78.6)      37 ( 94.9)    0.099
#                              2              6 ( 21.4)       2 (  5.1)
#   LN..._No (mean (SD))                   1.29 (1.49)     3.67 (4.47)     0.009
#   LN_removed (mean (SD))                21.21 (12.54)   24.51 (11.25)    0.264
#   CA19_9_Base (mean (SD))              103.31 (212.94) 343.43 (1089.82)  0.255
#   CEA_Base (mean (SD))                   3.60 (2.68)    26.19 (131.67)   0.368
#   cf_DNA_Pre (mean (SD))                 0.86 (0.61)     1.15 (1.32)     0.277
#   KRAS_C_Pre (mean (SD))                 0.30 (0.54)     0.94 (2.45)     0.180
#   PFS_mo (mean (SD))                    55.12 (14.49)    6.41 (3.59)    <0.001
#   PFS_event_Up220713 (%)     0             11 ( 39.3)       0 (  0.0)   <0.001
#                              1             17 ( 60.7)      39 (100.0)
#   SubGroup (%)               Over3Yrs      28 (100.0)       0 (  0.0)   <0.001
#                              Within1Yr      0 (  0.0)      39 (100.0)

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
# # TCGA Clinical dataset

# %%
library(survival)

# %%
TCGA_clinical <- read.csv("/mnt/e/TCGA/PAAD/clinical/clinical.tsv", sep="\t")
TCGA_clinical[TCGA_clinical == '\'--'] = NA
TCGA_clinical <- TCGA_clinical[,!colSums(is.na(TCGA_clinical)) > 320]
TCGA_clinical = TCGA_clinical[, c("case_submitter_id", "days_to_death", "gender", "race", "vital_status", "age_at_diagnosis", 
                  "ajcc_pathologic_t", "ajcc_pathologic_n", "ajcc_pathologic_m", "ajcc_pathologic_stage", "ajcc_staging_system_edition",
                  "days_to_last_follow_up", "morphology", "primary_diagnosis", "prior_malignancy", "prior_treatment", "site_of_resection_or_biopsy",
                  "tissue_or_organ_of_origin")]
TCGA_clinical <- TCGA_clinical[!duplicated(TCGA_clinical),]
TCGA_clinical$ajcc_pathologic_stage = gsub("B", "", gsub("A", "", TCGA_clinical$ajcc_pathologic_stage))
svs <- dir("/mnt/e/TCGA/PAAD/svs")

# %%
TCGA_clinical$Time = TCGA_clinical$days_to_last_follow_up
TCGA_clinical$Time[TCGA_clinical$vital_status == "Dead"] = TCGA_clinical$days_to_death[TCGA_clinical$vital_status == "Dead"]
TCGA_clinical <- TCGA_clinical[, !colnames(TCGA_clinical) %in% c("days_to_last_follow_up", "days_to_death")]

# %%
Variables <- c("gender", "race", "age_at_diagnosis", "ajcc_pathologic_t", "ajcc_pathologic_n", "ajcc_pathologic_m",
  "ajcc_pathologic_stage", "ajcc_staging_system_edition", "morphology", "primary_diagnosis", "prior_malignancy", 
  "prior_treatment", "site_of_resection_or_biopsy", "tissue_or_organ_of_origin")
col_idx = which(colnames(TCGA_clinical) %in% Variables)

# %%
dim(TCGA_clinical)
# Out:
# [1] 185  17

# %%
SurvivalData = Surv(as.numeric(TCGA_clinical$Time), TCGA_clinical$vital_status == "Dead")

# %%
i = i+1
table(TCGA_clinical[, col_idx[i]])
# Out:
#               Body of pancreas               Head of pancreas
#                             15                            137
# Overlapping lesion of pancreas                  Pancreas, NOS
#                              2                             17
#               Tail of pancreas
#                             14

# %%
table(rowSums(is.na(TCGA_clinical)))
# Out:
#   0   1   2
# 181   3   1

# %%
coxRes <- list()
for(i in 1:length(col_idx)) coxRes[[i]] <- coef(summary(coxph(SurvivalData ~ TCGA_clinical[, col_idx[i]], data=TCGA_clinical)))
do.call(rbind, coxRes)
# Out:
# Warning message in coxph.fit(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  4 ; coefficient may be infinite. ”
# Warning message in coxph.fit(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  1,3,4,5 ; coefficient may be infinite. ”
# Warning message in coxph.fit(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  2,5 ; coefficient may be infinite. ”
# Warning message in coxph.fit(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  2 ; coefficient may be infinite. ”
# Warning message in coxph.fit(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  2 ; coefficient may be infinite. ”
#                                                             coef
# TCGA_clinical[, col_idx[i]]male                              -0.181417448
# TCGA_clinical[, col_idx[i]]black or african american          0.426609925
# TCGA_clinical[, col_idx[i]]not reported                       0.511943802
# TCGA_clinical[, col_idx[i]]white                              0.270814844
# TCGA_clinical[, col_idx[i]]                                   0.000076767
# TCGA_clinical[, col_idx[i]]T2                                 0.371220698
# TCGA_clinical[, col_idx[i]]T3                                 1.058054891
# TCGA_clinical[, col_idx[i]]T4                                 0.741305155
# TCGA_clinical[, col_idx[i]]TX                               -15.173792005
# TCGA_clinical[, col_idx[i]]N1                                 0.777238523
# TCGA_clinical[, col_idx[i]]N1b                                0.554688481
# TCGA_clinical[, col_idx[i]]NX                                -0.021801387
# TCGA_clinical[, col_idx[i]]M1                                -0.032473150
# TCGA_clinical[, col_idx[i]]MX                                -0.264027449
# TCGA_clinical[, col_idx[i]]Stage II                           0.894856590
# TCGA_clinical[, col_idx[i]]Stage III                          0.673183916
# TCGA_clinical[, col_idx[i]]Stage IV                           0.888239152
# TCGA_clinical[, col_idx[i]]6th                               -0.923548363
# TCGA_clinical[, col_idx[i]]7th                               -0.493009685
# TCGA_clinical[, col_idx[i]]8140/3                            17.655568492
# TCGA_clinical[, col_idx[i]]8246/3                            -0.212424071
# TCGA_clinical[, col_idx[i]]8255/3                            18.976711025
# TCGA_clinical[, col_idx[i]]8480/3                            18.525757897
# TCGA_clinical[, col_idx[i]]8500/3                            18.176053793
# TCGA_clinical[, col_idx[i]]Adenocarcinoma, NOS               -1.321142533
# TCGA_clinical[, col_idx[i]]Carcinoma, undifferentiated, NOS -18.976710523
# TCGA_clinical[, col_idx[i]]Infiltrating duct carcinoma, NOS  -0.800657233
# TCGA_clinical[, col_idx[i]]Mucinous adenocarcinoma           -0.450953129
# TCGA_clinical[, col_idx[i]]Neuroendocrine carcinoma, NOS    -19.189135096
# TCGA_clinical[, col_idx[i]]yes                               -0.184666624
# TCGA_clinical[, col_idx[i]]Yes                                0.809862474
# TCGA_clinical[, col_idx[i]]Head of pancreas                   1.441263242
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   -14.734337822
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                      1.493094662
# TCGA_clinical[, col_idx[i]]Tail of pancreas                   1.123632395
# TCGA_clinical[, col_idx[i]]Head of pancreas                   1.441263242
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   -14.734337822
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                      1.493094662
# TCGA_clinical[, col_idx[i]]Tail of pancreas                   1.123632395
#                                                             exp(coef)
# TCGA_clinical[, col_idx[i]]male                             8.340871e-01
# TCGA_clinical[, col_idx[i]]black or african american        1.532055e+00
# TCGA_clinical[, col_idx[i]]not reported                     1.668531e+00
# TCGA_clinical[, col_idx[i]]white                            1.311032e+00
# TCGA_clinical[, col_idx[i]]                                 1.000077e+00
# TCGA_clinical[, col_idx[i]]T2                               1.449503e+00
# TCGA_clinical[, col_idx[i]]T3                               2.880762e+00
# TCGA_clinical[, col_idx[i]]T4                               2.098673e+00
# TCGA_clinical[, col_idx[i]]TX                               2.571022e-07
# TCGA_clinical[, col_idx[i]]N1                               2.175456e+00
# TCGA_clinical[, col_idx[i]]N1b                              1.741398e+00
# TCGA_clinical[, col_idx[i]]NX                               9.784345e-01
# TCGA_clinical[, col_idx[i]]M1                               9.680484e-01
# TCGA_clinical[, col_idx[i]]MX                               7.679525e-01
# TCGA_clinical[, col_idx[i]]Stage II                         2.446985e+00
# TCGA_clinical[, col_idx[i]]Stage III                        1.960469e+00
# TCGA_clinical[, col_idx[i]]Stage IV                         2.430846e+00
# TCGA_clinical[, col_idx[i]]6th                              3.971075e-01
# TCGA_clinical[, col_idx[i]]7th                              6.107854e-01
# TCGA_clinical[, col_idx[i]]8140/3                           4.652817e+07
# TCGA_clinical[, col_idx[i]]8246/3                           8.086217e-01
# TCGA_clinical[, col_idx[i]]8255/3                           1.743737e+08
# TCGA_clinical[, col_idx[i]]8480/3                           1.110796e+08
# TCGA_clinical[, col_idx[i]]8500/3                           7.829966e+07
# TCGA_clinical[, col_idx[i]]Adenocarcinoma, NOS              2.668303e-01
# TCGA_clinical[, col_idx[i]]Carcinoma, undifferentiated, NOS 5.734814e-09
# TCGA_clinical[, col_idx[i]]Infiltrating duct carcinoma, NOS 4.490337e-01
# TCGA_clinical[, col_idx[i]]Mucinous adenocarcinoma          6.370207e-01
# TCGA_clinical[, col_idx[i]]Neuroendocrine carcinoma, NOS    4.637293e-09
# TCGA_clinical[, col_idx[i]]yes                              8.313814e-01
# TCGA_clinical[, col_idx[i]]Yes                              2.247599e+00
# TCGA_clinical[, col_idx[i]]Head of pancreas                 4.226031e+00
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   3.989867e-07
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                    4.450848e+00
# TCGA_clinical[, col_idx[i]]Tail of pancreas                 3.076007e+00
# TCGA_clinical[, col_idx[i]]Head of pancreas                 4.226031e+00
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   3.989867e-07
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                    4.450848e+00
# TCGA_clinical[, col_idx[i]]Tail of pancreas                 3.076007e+00
#                                                             se(coef)
# TCGA_clinical[, col_idx[i]]male                             2.005439e-01
# TCGA_clinical[, col_idx[i]]black or african american        6.341376e-01
# TCGA_clinical[, col_idx[i]]not reported                     6.728166e-01
# TCGA_clinical[, col_idx[i]]white                            4.613724e-01
# TCGA_clinical[, col_idx[i]]                                 2.737976e-05
# TCGA_clinical[, col_idx[i]]T2                               7.861813e-01
# TCGA_clinical[, col_idx[i]]T3                               7.201360e-01
# TCGA_clinical[, col_idx[i]]T4                               1.006077e+00
# TCGA_clinical[, col_idx[i]]TX                               2.592924e+03
# TCGA_clinical[, col_idx[i]]N1                               2.581473e-01
# TCGA_clinical[, col_idx[i]]N1b                              6.296395e-01
# TCGA_clinical[, col_idx[i]]NX                               7.520926e-01
# TCGA_clinical[, col_idx[i]]M1                               5.968090e-01
# TCGA_clinical[, col_idx[i]]MX                               2.058019e-01
# TCGA_clinical[, col_idx[i]]Stage II                         3.967550e-01
# TCGA_clinical[, col_idx[i]]Stage III                        8.069537e-01
# TCGA_clinical[, col_idx[i]]Stage IV                         6.976045e-01
# TCGA_clinical[, col_idx[i]]6th                              1.038829e+00
# TCGA_clinical[, col_idx[i]]7th                              1.008521e+00
# TCGA_clinical[, col_idx[i]]8140/3                           1.338373e+04
# TCGA_clinical[, col_idx[i]]8246/3                           1.363894e+04
# TCGA_clinical[, col_idx[i]]8255/3                           1.338373e+04
# TCGA_clinical[, col_idx[i]]8480/3                           1.338373e+04
# TCGA_clinical[, col_idx[i]]8500/3                           1.338373e+04
# TCGA_clinical[, col_idx[i]]Adenocarcinoma, NOS              1.072585e+00
# TCGA_clinical[, col_idx[i]]Carcinoma, undifferentiated, NOS 1.338368e+04
# TCGA_clinical[, col_idx[i]]Infiltrating duct carcinoma, NOS 1.010026e+00
# TCGA_clinical[, col_idx[i]]Mucinous adenocarcinoma          1.160818e+00
# TCGA_clinical[, col_idx[i]]Neuroendocrine carcinoma, NOS    2.626134e+03
# TCGA_clinical[, col_idx[i]]yes                              3.517745e-01
# TCGA_clinical[, col_idx[i]]Yes                              1.008825e+00
# TCGA_clinical[, col_idx[i]]Head of pancreas                 5.235190e-01
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   2.688738e+03
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                    5.883290e-01
# TCGA_clinical[, col_idx[i]]Tail of pancreas                 6.548727e-01
# TCGA_clinical[, col_idx[i]]Head of pancreas                 5.235190e-01
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   2.688738e+03
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                    5.883290e-01
# TCGA_clinical[, col_idx[i]]Tail of pancreas                 6.548727e-01
#                                                             z
# TCGA_clinical[, col_idx[i]]male                             -9.046272e-01
# TCGA_clinical[, col_idx[i]]black or african american         6.727403e-01
# TCGA_clinical[, col_idx[i]]not reported                      7.608965e-01
# TCGA_clinical[, col_idx[i]]white                             5.869767e-01
# TCGA_clinical[, col_idx[i]]                                  2.803786e+00
# TCGA_clinical[, col_idx[i]]T2                                4.721820e-01
# TCGA_clinical[, col_idx[i]]T3                                1.469243e+00
# TCGA_clinical[, col_idx[i]]T4                                7.368271e-01
# TCGA_clinical[, col_idx[i]]TX                               -5.852001e-03
# TCGA_clinical[, col_idx[i]]N1                                3.010834e+00
# TCGA_clinical[, col_idx[i]]N1b                               8.809620e-01
# TCGA_clinical[, col_idx[i]]NX                               -2.898764e-02
# TCGA_clinical[, col_idx[i]]M1                               -5.441130e-02
# TCGA_clinical[, col_idx[i]]MX                               -1.282921e+00
# TCGA_clinical[, col_idx[i]]Stage II                          2.255439e+00
# TCGA_clinical[, col_idx[i]]Stage III                         8.342286e-01
# TCGA_clinical[, col_idx[i]]Stage IV                          1.273270e+00
# TCGA_clinical[, col_idx[i]]6th                              -8.890279e-01
# TCGA_clinical[, col_idx[i]]7th                              -4.888443e-01
# TCGA_clinical[, col_idx[i]]8140/3                            1.319181e-03
# TCGA_clinical[, col_idx[i]]8246/3                           -1.557482e-05
# TCGA_clinical[, col_idx[i]]8255/3                            1.417894e-03
# TCGA_clinical[, col_idx[i]]8480/3                            1.384200e-03
# TCGA_clinical[, col_idx[i]]8500/3                            1.358071e-03
# TCGA_clinical[, col_idx[i]]Adenocarcinoma, NOS              -1.231737e+00
# TCGA_clinical[, col_idx[i]]Carcinoma, undifferentiated, NOS -1.417900e-03
# TCGA_clinical[, col_idx[i]]Infiltrating duct carcinoma, NOS -7.927093e-01
# TCGA_clinical[, col_idx[i]]Mucinous adenocarcinoma          -3.884786e-01
# TCGA_clinical[, col_idx[i]]Neuroendocrine carcinoma, NOS    -7.306989e-03
# TCGA_clinical[, col_idx[i]]yes                              -5.249574e-01
# TCGA_clinical[, col_idx[i]]Yes                               8.027782e-01
# TCGA_clinical[, col_idx[i]]Head of pancreas                  2.753030e+00
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   -5.480021e-03
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                     2.537857e+00
# TCGA_clinical[, col_idx[i]]Tail of pancreas                  1.715803e+00
# TCGA_clinical[, col_idx[i]]Head of pancreas                  2.753030e+00
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   -5.480021e-03
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                     2.537857e+00
# TCGA_clinical[, col_idx[i]]Tail of pancreas                  1.715803e+00
#                                                             Pr(>|z|)
# TCGA_clinical[, col_idx[i]]male                             0.365662932
# TCGA_clinical[, col_idx[i]]black or african american        0.501112526
# TCGA_clinical[, col_idx[i]]not reported                     0.446718865
# TCGA_clinical[, col_idx[i]]white                            0.557219343
# TCGA_clinical[, col_idx[i]]                                 0.005050640
# TCGA_clinical[, col_idx[i]]T2                               0.636796865
# TCGA_clinical[, col_idx[i]]T3                               0.141766864
# TCGA_clinical[, col_idx[i]]T4                               0.461227492
# TCGA_clinical[, col_idx[i]]TX                               0.995330805
# TCGA_clinical[, col_idx[i]]N1                               0.002605312
# TCGA_clinical[, col_idx[i]]N1b                              0.378338415
# TCGA_clinical[, col_idx[i]]NX                               0.976874452
# TCGA_clinical[, col_idx[i]]M1                               0.956607478
# TCGA_clinical[, col_idx[i]]MX                               0.199519915
# TCGA_clinical[, col_idx[i]]Stage II                         0.024105815
# TCGA_clinical[, col_idx[i]]Stage III                        0.404152151
# TCGA_clinical[, col_idx[i]]Stage IV                         0.202922106
# TCGA_clinical[, col_idx[i]]6th                              0.373988083
# TCGA_clinical[, col_idx[i]]7th                              0.624951955
# TCGA_clinical[, col_idx[i]]8140/3                           0.998947446
# TCGA_clinical[, col_idx[i]]8246/3                           0.999987573
# TCGA_clinical[, col_idx[i]]8255/3                           0.998868685
# TCGA_clinical[, col_idx[i]]8480/3                           0.998895569
# TCGA_clinical[, col_idx[i]]8500/3                           0.998916417
# TCGA_clinical[, col_idx[i]]Adenocarcinoma, NOS              0.218047449
# TCGA_clinical[, col_idx[i]]Carcinoma, undifferentiated, NOS 0.998868680
# TCGA_clinical[, col_idx[i]]Infiltrating duct carcinoma, NOS 0.427947203
# TCGA_clinical[, col_idx[i]]Mucinous adenocarcinoma          0.697661876
# TCGA_clinical[, col_idx[i]]Neuroendocrine carcinoma, NOS    0.994169918
# TCGA_clinical[, col_idx[i]]yes                              0.599612823
# TCGA_clinical[, col_idx[i]]Yes                              0.422102923
# TCGA_clinical[, col_idx[i]]Head of pancreas                 0.005904657
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   0.995627598
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                    0.011153368
# TCGA_clinical[, col_idx[i]]Tail of pancreas                 0.086198153
# TCGA_clinical[, col_idx[i]]Head of pancreas                 0.005904657
# TCGA_clinical[, col_idx[i]]Overlapping lesion of pancreas   0.995627598
# TCGA_clinical[, col_idx[i]]Pancreas, NOS                    0.011153368
# TCGA_clinical[, col_idx[i]]Tail of pancreas                 0.086198153

# %%
SurvivalData = Surv(as.numeric(TCGA_clinical$Time), TCGA_clinical$vital_status == "Dead")

# %%
tmp_clinical <- TCGA_clinical
tmp_clinical$age_group <- ifelse(tmp_clinical$age_at_diagnosis >= sort(tmp_clinical$age_at_diagnosis), ">=median", "<median")

# 생존 분석 모델
fit <- survfit(SurvivalData ~ age_group, data = tmp_clinical)

# 그래프 그리기
ggsurvplot(fit, data = tmp_clinical, pval = TRUE, conf.int = TRUE,
           palette = c("#E7B800", "#2E9FDF"),
           xlab = "Time (days)", ylab = "Survival probability",
           title = "Survival Curves Split by Age Median")
# Out:
# plot without title
